# %%
import csv

# %%
 with open("speed5trial1.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    data = []
    for row in reader:
        data.append(row)
    
#print(data)

data_float = []
for i in range(1, len(data)):
    data_float.append([float(data[i][0]),float(data[i][1])])
#print(data_float)

# %%
var('x sigma mu M')
assume(sigma>0)
assume(M>0)
model(x) = M * (1/sqrt(2*pi*sigma**2)) * exp(-(x-mu)**2 / (2*sigma**2))
fit_result1 = find_fit(data_float, model, initial_guess=[.1, 75, 11])  # Replace with your initial guesses
print(fit_result1)
# Out:
# [M == 74845.22831517116, mu == 92.30716126881, sigma == 42.333081415524326]

# %%
N(73505.1038 * (1/sqrt(2*pi*(15.42589)**2)))
# Out:
# 1900.97905087590

# %%
plot1 = list_plot(data_float,color='green')
show(plot1)
# Out:
# Graphics object consisting of 1 graphics primitive
